# %%
# !pip install -U pandasql

# %%
import pandas as pd
from pandasql import sqldf

# %%
jugadores = pd.read_csv('datasets/nba_jugador.csv', sep=';')
nacimientos = pd.read_csv('datasets/nba_nacimientos.csv', sep=';')
universidades = pd.read_csv('datasets/nba_universidades.csv', sep=';')

trabajadores = pd.read_csv('datasets/trabajadores.csv')

# %%
# Define the function used for the queries
pysqldf = lambda q: sqldf(q, globals())

# %% [markdown]
# # Bloque 1
#
# **Datasets: jugadores / universidades / nacimientos**
#
# Escribir una consulta para encontrar la fecha y lugar de nacimiento asociado a cada jugador (siempre que sea posible encontrar el nombre del jugador).

# %%
query = ''''''

pysqldf(query)

# %% [markdown]
# Escribir una consulta para mostrar el nombre, el ID de jugador  y lugar de nacimientos de los jugadores (Siempre que haya información sobre el nacimiento).

# %%
query = ''''''

pysqldf(query)

# %% [markdown]
# Escribir una consulta para mostrar el nombre, el ID de jugador  y lugar de nacimientos de los jugadores (siempre que sea posible mostrar TODA la información)

# %%
query = ''''''

pysqldf(query)

# %% [markdown]
# Escribir una consulta para buscar el nombre, ID de jugador y lugar y fecha de nacimiento de todos aquellos jugadores que hayan estudiado en Columbia University.

# %%
query = ''''''

pysqldf(query)

# %% [markdown]
# Escribir una consulta para buscar el ID, la fecha de nacimiento de los jugadores que nacieron después después del jugador llamado "Jim McMillian".

# %%
query = ''''''

pysqldf(query)

# %% [markdown]
# **Dataset: empleados**
#
# Escribir una consulta para encontrar el ID de empleado, nombre (last_name) junto con el ID de su manager y el nombre del manager (last_name).

# %%
query = ''''''

pysqldf(query)
